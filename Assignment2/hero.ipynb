# %%
from character import Character

# %%
class Hero(Character):
    def __init__(self):
        super().__init__()  # Call parent constructor
    def hero_attacks(self, monster):
        ascii_image = """
                                @@   @@ 
                                @    @  
                                @   @   
               @@@@@@          @@  @    
            @@       @@        @ @@     
           @%         @     @@@ @       
            @        @@     @@@@@     
               @@@@@        @@       
               @    @@@@                
          @@@ @@                        
       @@     @                         
   @@*       @                          
   @        @@                          
           @@                                                    
         @   @@@@@@@                    
        @            @                  
      @              @

# %% [markdown]
#
# <br>
#         print(ascii_image)<br>
#         print("Hero attacks Monster!")<br>
#         print(f"Hero Strength: {self.combat_strength}, Monster Health: {monster.health_points}")<br>
#         if self.combat_strength >= monster.health_points:<br>
#             monster.health_points = 0<br>
#             print("Hero defeated the monster!")<br>
#         else:<br>
#             monster.health_points -= self.combat_strength<br>
#             print(f"Monster's remaining health: {monster.health_points}")<br>
#     def __del__(self):<br>
#         print("The Hero object is being destroyed by the garbage collector")<br>
#         super().__del__()  # Call parent destructor
